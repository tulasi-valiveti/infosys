# %% [markdown]
# **Milestone 3: Route, Cancellation, and Seasonal Insights**

# %% [markdown]
# Week 5: Route and Airport-Level Analysis

# %%
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.3.0)
# Requirement already satisfied: requests in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from requests->folium) (2024.8.30)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd


df = pd.read_csv("D:\infosys_project\Flight_delay.csv")

# Show first 5 rows
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\i'
# <>:4: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\TULASI V\AppData\Local\Temp\ipykernel_21444\3091641789.py:4: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv("D:\infosys_project\Flight_delay.csv")
#    DayOfWeek        Date  DepTime  ArrTime  CRSArrTime UniqueCarrier  \
# 0          4  03-01-2019     1829     1959        1925            WN
# 1          4  03-01-2019     1937     2037        1940            WN
# 2          4  03-01-2019     1644     1845        1725            WN
# 3          4  03-01-2019     1452     1640        1625            WN
# 4          4  03-01-2019     1323     1526        1510            WN
#
#                   Airline  FlightNum TailNum  ActualElapsedTime  ...  TaxiIn  \
# 0  Southwest Airlines Co.       3920  N464WN                 90  ...       3
# 1  Southwest Airlines Co.        509  N763SW                240  ...       3
# 2  Southwest Airlines Co.       1333  N334SW                121  ...       6
# 3  Southwest Airlines Co.        675  N286WN                228  ...       7
# 4  Southwest Airlines Co.          4  N674AA                123  ...       4
#
#    TaxiOut  Cancelled  CancellationCode Diverted CarrierDelay WeatherDelay  \
# 0       10          0                 N        0            2            0
# 1        7          0                 N        0           10            0
# 2        8          0                 N        0            8            0
# 3        8          0                 N        0            3            0
# 4        9          0                 N        0            0            0
#
#   NASDelay  SecurityDelay  LateAircraftDelay
# 0        0              0                 32
# 1        0              0                 47
# 2        0              0                 72
# 3        0              0                 12
# 4        0              0                 16
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484551 entries, 0 to 484550
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DayOfWeek          484551 non-null  int64
#  1   Date               484551 non-null  object
#  2   DepTime            484551 non-null  int64
#  3   ArrTime            484551 non-null  int64
#  4   CRSArrTime         484551 non-null  int64
#  5   UniqueCarrier      484551 non-null  object
#  6   Airline            484551 non-null  object
#  7   FlightNum          484551 non-null  int64
#  8   TailNum            484551 non-null  object
#  9   ActualElapsedTime  484551 non-null  int64
#  10  CRSElapsedTime     484551 non-null  int64
#  11  AirTime            484551 non-null  int64
#  12  ArrDelay           484551 non-null  int64
#  13  DepDelay           484551 non-null  int64
#  14  Origin             484551 non-null  object
#  15  Org_Airport        483374 non-null  object
#  16  Dest               484551 non-null  object
#  17  Dest_Airport       483072 non-null  object
#  18  Distance           484551 non-null  int64
#  19  TaxiIn             484551 non-null  int64
#  20  TaxiOut            484551 non-null  int64
#  21  Cancelled          484551 non-null  int64
#  22  CancellationCode   484551 non-null  object
#  23  Diverted           484551 non-null  int64
#  24  CarrierDelay       484551 non-null  int64
#  25  WeatherDelay       484551 non-null  int64
#  26  NASDelay           484551 non-null  int64
#  27  SecurityDelay      484551 non-null  int64
#  28  LateAircraftDelay  484551 non-null  int64
# dtypes: int64(20), object(9)
# memory usage: 107.2+ MB

# %%
import pandas as pd
import plotly.express as px

# Load dataset
df = pd.read_csv("D:\infosys_project\Flight_delay.csv")

# Create route column if not exists
if 'Route' not in df.columns:
    df['Route'] = df['Origin'] + "-" + df['Dest']

# Top 10 busiest routes
top_routes = df['Route'].value_counts().head(10).reset_index()
top_routes.columns = ['Route', 'Count']

# Plotly bar chart
fig = px.bar(
    top_routes,
    x='Route',
    y='Count',
    text='Count',
    title='Top 10 Busiest Origin-Destination Pairs',
    color='Count',
    color_continuous_scale='Plasma'
)
fig.update_traces(textposition='outside')
fig.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# <>:5: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\TULASI V\AppData\Local\Temp\ipykernel_21444\3320275341.py:5: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv("D:\infosys_project\Flight_delay.csv")

# %%
import numpy as np

# Calculate average delay per origin airport
airport_delay = df.groupby('Origin')['ArrDelay'].mean().reset_index()

fig = px.density_heatmap(
    airport_delay,
    x='Origin',
    y='ArrDelay',
    nbinsx=len(airport_delay),
    title='Average Arrival Delay by Origin Airport',
    color_continuous_scale='RdYlBu_r'
)
fig.show()

# %%
route_delay = df.groupby('Route')['ArrDelay'].mean().reset_index()

fig = px.density_heatmap(
    route_delay,
    x='Route',
    y='ArrDelay',
    title='Average Delay per Route',
    color_continuous_scale='Viridis'
)
fig.show()

# %%
#Example lookup table (you can extend this)
airport_coords = {
    'ATL': (33.6407, -84.4277),
    'LAX': (33.9416, -118.4085),
    'ORD': (41.9742, -87.9073),
    'DFW': (32.8998, -97.0403),
    'DEN': (39.8561, -104.6737),
    'JFK': (40.6413, -73.7781),
    'SFO': (37.6213, -122.3790),
    'SEA': (47.4502, -122.3088),
    'MIA': (25.7959, -80.2870),
    'LAS': (36.0840, -115.1537),
    'YYZ': (43.6777, -79.6248)   
}



# Map coordinates to each row
df['Latitude'] = df['Org_Airport'].map(lambda x: airport_coords.get(x, (None, None))[0])
df['Longitude'] = df['Org_Airport'].map(lambda x: airport_coords.get(x, (None, None))[1])

# %%
# Map coordinates to each row
df['Latitude'] = df['Org_Airport'].map(lambda x: airport_coords.get(x, (None, None))[0])
df['Longitude'] = df['Org_Airport'].map(lambda x: airport_coords.get(x, (None, None))[1])
import numpy as np

# Assign random coordinates for visualization
unique_airports = df['Org_Airport'].unique()
coords = {a: (np.random.uniform(25, 49), np.random.uniform(-125, -67)) for a in unique_airports}

df["Latitude"] = df["Org_Airport"].map(lambda x: coords[x][0])
df["Longitude"] = df["Org_Airport"].map(lambda x: coords[x][1])

# %%
# !pip install branca
# Out:
# Requirement already satisfied: branca in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (0.8.2)
# Requirement already satisfied: jinja2>=3 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from branca) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tulasi v\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3->branca) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import folium
from branca.colormap import LinearColormap


# Ensure necessary columns
required_cols = ['Origin', 'Org_Airport', 'Latitude', 'Longitude', 'ArrDelay']
assert all(col in df.columns for col in required_cols), "Dataset missing one or more required columns!"

# Aggregate: flight count + average delay
airport_stats = (
    df.groupby(['Origin', 'Org_Airport', 'Latitude', 'Longitude'])
    .agg(Count=('Origin', 'size'), AvgDelay=('ArrDelay', 'mean'))
    .reset_index()
)

# Create color scale (green → yellow → red)

colormap =LinearColormap(
    colors=['green', 'yellow', 'red'],
    vmin=airport_stats['AvgDelay'].min(),
    vmax=airport_stats['AvgDelay'].max(),
    caption="Average Arrival Delay (minutes)"
)
colormap.caption = "Average Arrival Delay (minutes)"

airport_stats.head()
# Out:
#   Origin                          Org_Airport   Latitude   Longitude  Count  \
# 0    ABE  Lehigh Valley International Airport  37.000633 -114.801167    141
# 1    ABI             Abilene Regional Airport  28.153536  -77.202786    157
# 2    ABQ    Albuquerque International Sunport  30.949820 -116.791422   3026
# 3    ABY   Southwest Georgia Regional Airport  28.784902  -97.652084    103
# 4    ACT                Waco Regional Airport  43.736705 -104.188653    138
#
#      AvgDelay
# 0   86.921986
# 1  100.898089
# 2   50.931923
# 3   66.427184
# 4   61.608696

# %%
import folium
from folium.plugins import HeatMap

# Aggregate total flights per airport
airport_traffic = df.groupby(['Origin', 'Org_Airport', 'Latitude', 'Longitude']).size().reset_index(name='Count')

# Initialize folium map
m = folium.Map(location=[39.8283, -98.5795], zoom_start=4, tiles='CartoDB positron')

# Add circles for busiest airports
for _, row in airport_traffic.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=row['Count'] / airport_traffic['Count'].max() * 20,
        popup=f"{row['Org_Airport']} ({row['Origin']}) - {row['Count']} flights",
        color='blue',
        fill=True,
        fill_opacity=0.6
    ).add_to(m)

m.save('busiest_airports.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89560bc1a9643aab0196a078d4be4619 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89560bc1a9643aab0196a078d4be4619&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89560bc1a9643aab0196a078d4be4619 = L.map(
#                 &quot;map_89560bc1a9643aab0196a078d4be4619&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a41b63e44ab33b25bae9fe6b7de3a802 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a41b63e44ab33b25bae9fe6b7de3a802.addTo(map_89560bc1a9643aab0196a078d4be4619);
#
#
#             var circle_marker_d52c3ce35194a6af3c52810b5b1a11ba = L.circleMarker(
#                 [37.00063262312004, -114.8011666974036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.060070295026094365, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_89560bc1a9643aab0196a078d4be4619);
#
#
#         var popup_a35a96fe1534c946f1f7496e7f10ca0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3adc9f506821321fa2ea4c807231c36e = $(`&lt;div id=&quot;html_3adc9f506821321fa2ea4c807231c36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lehigh Valley International Airport (ABE) - 141 flights&lt;/div&gt;`)[0];
#                 popup_a35a96fe1534c946f1f7496e7f10ca0b.setContent(html_3adc9f506821321fa2ea4c807231c36e);
#
#
#
#         circle_marker_d52c3ce35194a6af3c52810b5b1a11ba.bindPopup(popup_a35a96fe1534c946f1f7496e7f10ca0b)
#         ;
#
#
#
#
#             var circle_marker_938173d4b1ec98c919d41d4477105bf1 = L.circleMarker(
#                 [28.153535544717677, -77.20278581444262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.06688678240494196, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_89560bc1a9643aab0196a078d4be4619);
#
#
#         var popup_f6116e4362096ffa1600de10e4dea208 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ab22029343ca3e3cc71cb955fc4cd25 = $(`&lt;div id=&quot;html_7ab22029343ca3e3cc71cb955fc4cd25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abilene Regional Airport (ABI) - 157 flights&lt;/div&gt;`)[0];
#                 popup_f6116e4362096ffa1600de10e4dea208.setContent(html_7ab22029343ca3e3cc71cb955fc4cd25);
#
#
#
#         circle_marker_938173d4b1ec98c919d41d4477105bf1.bindPopup(popup_f6116e4362096ffa1600de10e4dea208)
#         ;
#
#
#
#
#             var circle_marker_51182f3ee87bb2707126da7d3391351c = L.circleMarker(
#                 [30.949820178533553, -116.79142173952349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2891681755245499, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_89560bc1a9643aab0196a078d4be4619);
#
#
#         var popup_ed47a77443c11355068fc688f05e9fb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8e3bc8130768c04d1d29a27e90dbe64 = $(`&lt;div id=&quot;html_d8e3bc8130768c04d1d29a27e90dbe64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albuquerque International Sunport (ABQ) - 3026 flights&lt;/div&gt;`)[0];

# %%
m_na = folium.Map(location=[39.5, -98.35], zoom_start=4, tiles='CartoDB positron')

for _, row in airport_stats.iterrows():
    if 15 < row['Latitude'] < 72 and -170 < row['Longitude'] < -30:
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=max(3, row['Count'] / airport_stats['Count'].max() * 20),
            color=colormap(row['AvgDelay']),
            fill=True,
            fill_color=colormap(row['AvgDelay']),
            fill_opacity=0.8,
            popup=folium.Popup(
                f"<b>{row['Org_Airport']} ({row['Origin']})</b><br>"
                f"Flights: {row['Count']}<br>"
                f"Avg Delay: {row['AvgDelay']:.2f} mins"
            ),
        ).add_to(m_na)

colormap.add_to(m_na)
m_na.save("busiest_airports_NorthAmerica_delay.html")
m_na
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d02c37449126a0900bb6dff94047af38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d02c37449126a0900bb6dff94047af38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d02c37449126a0900bb6dff94047af38 = L.map(
#                 &quot;map_d02c37449126a0900bb6dff94047af38&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_830b7bfb138a2268e90d93ed82914756 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_830b7bfb138a2268e90d93ed82914756.addTo(map_d02c37449126a0900bb6dff94047af38);
#
#
#             var circle_marker_cbd6713d85db9efc5f20550b5dad8fe5 = L.circleMarker(
#                 [37.00063262312004, -114.8011666974036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#cae500ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#cae500ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d02c37449126a0900bb6dff94047af38);
#
#
#         var popup_19f2aa2f2df171ddb7eda699fcb47443 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b15bcf9f1845418ae6f31df0bd2e827e = $(`&lt;div id=&quot;html_b15bcf9f1845418ae6f31df0bd2e827e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lehigh Valley International Airport (ABE)&lt;/b&gt;&lt;br&gt;Flights: 141&lt;br&gt;Avg Delay: 86.92 mins&lt;/div&gt;`)[0];
#                 popup_19f2aa2f2df171ddb7eda699fcb47443.setContent(html_b15bcf9f1845418ae6f31df0bd2e827e);
#
#
#
#         circle_marker_cbd6713d85db9efc5f20550b5dad8fe5.bindPopup(popup_19f2aa2f2df171ddb7eda699fcb47443)
#         ;
#
#
#
#
#             var circle_marker_f76a238657331d7a674e4200098a42c2 = L.circleMarker(
#                 [28.153535544717677, -77.20278581444262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f5fa00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f5fa00ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d02c37449126a0900bb6dff94047af38);
#
#
#         var popup_b7092ae2a1e0e7ee31748a991a2058f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca78e2351707eef6800e04d9d77b2721 = $(`&lt;div id=&quot;html_ca78e2351707eef6800e04d9d77b2721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Abilene Regional Airport (ABI)&lt;/b&gt;&lt;br&gt;Flights: 157&lt;br&gt;Avg Delay: 100.90 mins&lt;/div&gt;`)[0];
#                 popup_b7092ae2a1e0e7ee31748a991a2058f2.setContent(html_ca78e2351707eef6800e04d9d77b2721);
#
#
#
#         circle_marker_f76a238657331d7a674e4200098a42c2.bindPopup(popup_b7092ae2a1e0e7ee31748a991a2058f2)
#         ;
#
#
#
#
#             var circle_marker_63392235b31ee7c11ea5e07877b9ae09 = L.circleMarker(
#                 [30.949820178533553, -116.79142173952349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5cae00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#5cae00ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d02c37449126a0900bb6dff94047af38);
#
#
#         var popup_009ddf4fe7f9eccf0720745dc4a98e01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dffbf1868da2fce6315fb91fedba9fd8 = $(`&
